# %%
#| hide
from HexMagic.core import *

# %% [markdown]
# # HexMagic
#
# > This is a hex map generation system that outputs svg files

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install HexMagic in Development mode

# %% [markdown]
# ```sh
# # make sure HexMagic package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to HexMagic
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %%
from HexMagic.core import MapPath, MapSize, MapRect, MapCord , PrimitiveDemo
from HexMagic.core import Hex
from HexMagic.core import StyleCSS,  SVGBuilder
from HexMagic.core import HexGrid, HexPosition ,  HexRegion, GosperCurve, windy_edge , unique_windy_edge
from HexMagic.core import Terrain
from HexMagic.core import ClimatePreset, Climate

# %%
mySize = MapSize(480,480)
myBounds = MapRect(MapCord(0,0), mySize)
sampleMap, plates =  Terrain.fromSeeds(myBounds,radius=10)

sampleMap.colorMap()
sgrid = sampleMap.hexGrid
sgrid.builder.adjust("regions", sgrid.styleLayer(f=windy_edge(iterations=2, offset_factor=0.1)))


sampleMap.hexGrid.builder.show()
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_sw2oh_FtQeuzb7nDUxVLIQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@picocss/pico@latest/css/pico.min.css&quot;&gt;
#      &lt;style&gt;:root { --pico-font-size: 100%; }&lt;/style&gt;
#      &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5/themes.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div&gt;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;utf-8&#x27;?&gt;
# &lt;svg  width=&quot;832.72&quot; height=&quot;715.0&quot; viewBox=&quot;0 0 832.72 715.0&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;
# &lt;title&gt; Untitled &lt;/title&gt;
#   &lt;style&gt;
# .sealevel {
#   fill:#81b1e1ff;
# }
# .Summits {
#   stroke:#333333;
#   stroke-width:1.5;
#   opacity:0.9;
#   fill:#E65100;
# }
# .Summits:hover {
#   fill:#ac6139;
#   cursor:pointer;
# }
# .Snow {
#   stroke:#333333;
#   stroke-width:1.5;
#   opacity:0.9;
#   fill:#ffffff;
# }
# .Snow:hover {
#   fill:#ffffff;
#   cursor:pointer;
# }
# .Plains {
#   stroke:#333333;
#   stroke-width:1.5;
#   opacity:0.9;
#   fill:#9CCC65;
# }
# .Plains:hover {
#   fill:#9ab27e;
#   cursor:pointer;
# }
# .Peaks {
#   stroke:#333333;
#   stroke-width:1.5;
#   opacity:0.9;
#   fill:#BF360C;
# }
# .Peaks:hover {
#   fill:#924d38;
#   cursor:pointer;
# }
# .Mountains {
#   stroke:#333333;
#   stroke-width:1.5;
#   opacity:0.9;
#   fill:#F57C00;
# }
# .Mountains:hover {
#   fill:#b77b3d;
#   cursor:pointer;
# }
# .Lowland {
#   stroke:#333333;
#   stroke-width:1.5;
#   opacity:0.9;
#   fill:#66BB6A;
# }
# .Lowland:hover {
#   fill:#7ba57d;
#   cursor:pointer;
# }
# .Hills {
#   stroke:#333333;
#   stroke-width:1.5;
#   opacity:0.9;
#   fill:#D4E157;
# }
# .Hills:hover {
#   fill:#b8be79;
#   cursor:pointer;
# }
# .Highlands {
#   stroke:#333333;
#   stroke-width:1.5;
#   opacity:0.9;
#   fill:#FF9800;
# }
# .Highlands:hover {
#   fill:#bf8b3f;
#   cursor:pointer;
# }
# .Foothills {
#   stroke:#333333;
#   stroke-width:1.5;
#   opacity:0.9;
#   fill:#FFCA28;
# }
# .Foothills:hover {
#   fill:#c9ae5d;
#   cursor:pointer;
# }
#   &lt;/style&gt;
#
# &lt;g data-layer=&quot;root&quot;&gt;
#
# &lt;/g&gt;
# &lt;g data-layer=&quot;regions&quot;&gt;
#
# &lt;path d=&quot;M 0.0 650.0 L -1.0 647.6 L -1.0 645.0 L 0.0 642.6 L 0.0 640.0 L 0.0 640.0 L 0.0 640.0 L 0.0 640.0 L 0.0 640.0 L -2.7 639.7 L -5.0 638.4 L -6.7 636.3 L -9.0 635.0 L -10.0 632.6 L -10.0 630.0 L -9.0 627.6 L -9.0 625.0 L -6.7 623.7 L -4.0 623.4 L -1.7 622.1 L 0.0 620.0 L 0.0 620.0 L 0.0 620.0 L 0.0 620.0 L 0.0 620.0 L -1.0 617.6 L -1.0 615.0 L 0.0 612.6 L 0.0 610.0 L 0.0 610.0 L 0.0 610.0 L 0.0 610.0 L 0.0 610.0 L -2.7 609.7 L -5.0 608.4 L -6.7 606.3 L -9.0 605.0 L -10.0 602.6 L -10.0 600.0 L -9.0 597.6 L -9.0 595.0 L -6.7 593.7 L -4.0 593.4 L -1.7 592.1 L 0.0 590.0 L 0.0 590.0 L 0.0 590.0 L 0.0 590.0 L 0.0 590.0 L -1.0 587.6 L -1.0 585.0 L 0
.7 382.1 L 0.0 380.0 L 0.0 380.0 L 0.0 380.0 L 0.0 380.0 L 0.0 380.0 L -1.0 377.6 L -1.0 375.0 L 0.0 372.6 L 0.0 370.0 L 0.0 370.0 L 0.0 370.0 L 0.0 370.0 L 0.0 370.0 L -2.7 369.7 L -5.0 368.4 L -6.7 366.3 L -9.0 365.0 L -10.0 362.6 L -10.0 360.0 L -9.0 357.6 L -9.0 355.0 L -6.7 353.7 L -4.0 353.4 L -1.7 352.1 L 0.0 350.0 L 0.0 350.0 L 0.0 350.0 L 0.0 350.0 L 0.0 350.0 L -1.0 347.6 L -1.0 345.0 L 0.0 342.6 L 0.0 340.0 L 0.0 340.0 L 0.0 340.0 L 0.0 340.0 L 0.0 340.0 L -2.7 339.7 L -5.0 338.4 L -6.7 336.3 L -9.0 335.0 L -10.0 332.6 L -10.0 330.0 L -9.0 327.6 L -9.0 325.0 L -6.7 323.7 L -4.0 323.4 L -1.7 322.1 L 0.0 320.0 L 0.0 320.0 L 0.0 320.0 L 0.0 320.0 L 0.0 320.0 L -1.0 317.6 L -1.0 315.0 L 0.0 312.6 L 0.0 310.0 L 2.3 308.7 L 5.0 308.4 L 7.3 307.1 L 9.0 305.0 L 9.0 305.0 L 9.0 305.0 L 9.0 305.0 L 9.0 305.0 L 8.0 302.6 L 8.0 300.0 L 9.0 297.6 L 9.0 295.0 L 9.0 295.0 L 9.0 295.0 L 9.0 295.0 L 9.0 295.0 L 6.3 294.7 L 4.0 293.4 L 2.3 291.3 L 0.0 290.0 L -1.0 287.6 L -1.0 285.0 L 0.0 282.6 L 0.0 280.0 L 0.0 280.0 L 0.0 280.0 L 0.0 280.0 L 0.0 280.0 L -2.7 279.7 L -5.0 278.4 L -6.7 276.3 L -9.0 275.0 L -10.0 272.6 L -10.0 270.0 L -9.0 267.6 L -9.0 265.0 L -6.7 263.7 L -4.0 263.4 L -1.7 262.1 L 0.0 260.0 L 0.0 260.0 L 0.0 260.0 L 0.0 260.0 L 0.0 260.0 L -1.0 257.6 L -1.0 255.0 L 0.0 252.6 L 0.0 2 ...

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/ArthurConner/HexMagic.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c ArthurConner HexMagic
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install HexMagic
# ```
#
#
# [repo]: https://github.com/ArthurConner/HexMagic
# [docs]: https://ArthurConner.github.io/HexMagic/
# [pypi]: https://pypi.org/project/HexMagic/
# [conda]: https://anaconda.org/ArthurConner/HexMagic

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/ArthurConner/HexMagic
# [docs]: https://ArthurConner.github.io/HexMagic/
# [pypi]: https://pypi.org/project/HexMagic/
# [conda]: https://anaconda.org/ArthurConner/HexMagic

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
